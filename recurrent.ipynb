# %%
#Recurrent Neural Network (RNN)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
file_path = r"C:\Users\HP 15\Desktop\quiet_data_clean_corrected_2.csv"
quiet_df = pd.read_csv(file_path)
print(quiet_df.head())
# Out:
#     Time  PRN  Elev  Azim    Lat     Lon  vTEC  vTEC_corrected  \
# 0   3600  Z00     0    90  9.035  38.766  1.12            1.12
# 1   7200  Z00     0    90  9.035  38.766  0.26            0.26
# 2  10800  Z00     0    90  9.035  38.766  0.54            0.54
# 3  14400  Z00     0    90  9.035  38.766  4.03            4.03
# 4  18000  Z00     0    90  9.035  38.766  8.76            8.76
#
#       source_file  Hour  vTEC_log  DOY  YEAR  Kp_index  Sunspot_No  \
# 0  adisF3_001.10A     1  0.114221    1  2010       0.0          18
# 1  adisF3_001.10A     2 -1.343235    1  2010       0.0          18
# 2  adisF3_001.10A     3 -0.614336    1  2010       0.0          18
# 3  adisF3_001.10A     4  1.394014    1  2010       0.0          18
# 4  adisF3_001.10A     5  2.170310    1  2010       0.0          18
#
#    f10_7_index Condition
# 0         72.7     Quiet
# 1         72.7     Quiet
# 2         72.7     Quiet
# 3         72.7     Quiet
# 4         72.7     Quiet

# %%
quiet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62459 entries, 0 to 62458
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Time            62459 non-null  int64
#  1   PRN             62459 non-null  object
#  2   Elev            62459 non-null  int64
#  3   Azim            62459 non-null  int64
#  4   Lat             62459 non-null  float64
#  5   Lon             62459 non-null  float64
#  6   vTEC            62459 non-null  float64
#  7   vTEC_corrected  62459 non-null  float64
#  8   source_file     62459 non-null  object
#  9   Hour            62459 non-null  int64
#  10  vTEC_log        62459 non-null  float64
#  11  DOY             62459 non-null  int64
#  12  YEAR            62459 non-null  int64
#  13  Kp_index        62459 non-null  float64
#  14  Sunspot_No      62459 non-null  int64
#  15  f10_7_index     62459 non-null  float64
#  16  Condition       62459 non-null  object
# dtypes: float64(7), int64(7), object(3)
# memory usage: 8.1+ MB

# %%
quiet_df.head()
# Out:
#     Time  PRN  Elev  Azim    Lat     Lon  vTEC  vTEC_corrected  \
# 0   3600  Z00     0    90  9.035  38.766  1.12            1.12
# 1   7200  Z00     0    90  9.035  38.766  0.26            0.26
# 2  10800  Z00     0    90  9.035  38.766  0.54            0.54
# 3  14400  Z00     0    90  9.035  38.766  4.03            4.03
# 4  18000  Z00     0    90  9.035  38.766  8.76            8.76
#
#       source_file  Hour  vTEC_log  DOY  YEAR  Kp_index  Sunspot_No  \
# 0  adisF3_001.10A     1  0.114221    1  2010       0.0          18
# 1  adisF3_001.10A     2 -1.343235    1  2010       0.0          18
# 2  adisF3_001.10A     3 -0.614336    1  2010       0.0          18
# 3  adisF3_001.10A     4  1.394014    1  2010       0.0          18
# 4  adisF3_001.10A     5  2.170310    1  2010       0.0          18
#
#    f10_7_index Condition
# 0         72.7     Quiet
# 1         72.7     Quiet
# 2         72.7     Quiet
# 3         72.7     Quiet
# 4         72.7     Quiet

# %%
quiet_df['Sunspot_No'].unique()
# Out:
# array([ 18,  48,  71,  99, 124,  37,  12,   0,   6,  24,  21,  92,  95,
#        133,  40,  15,  17,  16,  47, 120, 130, 153,  51,  11,  13, 126,
#        150, 136,  70,  10,  36, 109, 162, 134,  35,  14,  28, 113, 160,
#         31,   7, 145,  61,   4,  25, 104, 154,  86,  32,  79, 156,  97,
#         22,  26, 148,  90,  20,  63, 163,   8,  52, 128,  38, 118, 119,
#         41,   3, 149, 110,  93,  45,  30,  80,  44, 141,  74,  58,  43,
#        116,  54, 105,  66,  33,  29, 102,  62,  56, 112, 129,  64,  75,
#         55,  67,  68,  60, 146,  57,  19,  23,  34,  76,  49, 100,  27,
#         69,  65,  72,  83,  77,  94,  53,  89,  59,   9, 127,  39, 144,
#        108,  42, 167, 103, 171, 147,   2,  84,  50,  46, 137, 158,  85,
#        161,  78,  87, 106,  82, 114, 107, 207, 220, 196, 155,  96,  73,
#         88, 111, 138, 115,  81,  91, 101, 132, 123, 122, 139, 151,  98,
#        135,   5, 121, 117, 125, 187, 199, 178, 140, 173, 168, 142, 165,
#        166, 164, 206, 183, 131, 174, 197, 182, 172, 194, 185, 143, 152,
#        169, 191, 181, 193, 180, 170, 177, 157, 192, 159, 176], dtype=int64)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, SimpleRNN
from tensorflow.keras.optimizers import Adam

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# 3. Feature engineering: cyclical encoding
quiet_df['DOY_s'] = np.sin(2 * np.pi * quiet_df['DOY'] / 365)
quiet_df['DOY_c'] = np.cos(2 * np.pi * quiet_df['DOY'] / 365)
quiet_df['HH_s'] = np.sin(2 * np.pi * quiet_df['Hour'] / 24)
quiet_df['HH_c'] = np.cos(2 * np.pi * quiet_df['Hour'] / 24)

# %%
from sklearn.preprocessing import StandardScaler

# === 1. Select features and target ===
features = ['DOY_s', 'DOY_c', 'HH_s', 'HH_c', 'Sunspot_No', 'Lat', 'Lon', 'f10_7_index', 'YEAR']
target = 'vTEC_corrected'

X = quiet_df[features]
y = quiet_df[target]

# %%
# === Separate by year ===
train_df = quiet_df[quiet_df['YEAR'] <= 2018]
test_df = quiet_df[quiet_df['YEAR'] >= 2019]

# === Split features and target ===
X_train = train_df[features]
y_train = train_df[target]

X_test = test_df[features]
y_test = test_df[target]

# === Scale after split to avoid data leakage ===
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# 5. Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in d:\users\hp 15\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\users\hp 15\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in d:\users\hp 15\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in d:\users\hp 15\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in d:\users\hp 15\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\hp 15\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\hp 15\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\hp 15\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\hp 15\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\users\hp 15\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\users\hp 15\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\users\hp 15\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\users\hp 15\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in d:\users\hp 15\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# Reshape for RNN: (samples, timesteps, features)
X_train_rnn = np.expand_dims(X_train_scaled, axis=1)
X_test_rnn = np.expand_dims(X_test_scaled, axis=1)

# Build RNN model
model = Sequential()
model.add(SimpleRNN(units=50, activation='tanh', input_shape=(X_train_rnn.shape[1], X_train_rnn.shape[2])))
model.add(Dense(1))

# Compile and train
model.compile(optimizer='adam', loss='mse')
model.fit(X_train_rnn, y_train, epochs=50, batch_size=32, verbose=0)

# Predictions
y_pred = model.predict(X_test_rnn).flatten()

# Evaluation
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Recurrent Neural Network (RNN)")
print(f"MSE: {mse:.4f}")
print(f"R²: {r2:.4f}")

# Scatter plot
plt.figure(figsize=(8, 5))
plt.scatter(y_test, y_pred, alpha=0.5, color='purple')
plt.xlabel("Actual vTEC_corrected")
plt.ylabel("Predicted vTEC_corrected")
plt.title("RNN: Actual vs Predicted")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.show()
# Out:
# D:\Users\HP 15\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Recurrent Neural Network (RNN)
# MSE: 11.5531
# R²: 0.8319
